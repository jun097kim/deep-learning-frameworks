# %%
import tensorflow as tf

# %%
# [None]: 1차원 array이고, 아무 값이나 들어올 수 있음
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %%
hypothesis = W * X + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    # train을 실행시킬 때 X, Y 값을 feed_dict로 넘겨줌
    # 세션을 실행시킬 때 리스트에 넣어 한꺼번에 실행시킬 수 있음
    # 그 결과로 내부적으로 W, b가 업데이트됨
    cost_val, W_val, b_val, _ = \
        sess.run([cost, W, b, train],
                 feed_dict={X: [1, 2, 3, 4, 5],
                            Y: [2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 3.8875823 [0.5624876] [1.0403485]
# 20 0.00060196774 [0.98330295] [1.1528778]
# 40 0.0004564513 [0.9861677] [1.1499053]
# 60 0.00039862134 [0.9870816] [1.1466392]
# 80 0.0003481167 [0.98792773] [1.1435847]
# 100 0.00030401238 [0.98871833] [1.1407304]
# 120 0.0002654978 [0.9894571] [1.138063]
# 140 0.00023185977 [0.99014765] [1.13557]
# 160 0.00020248652 [0.99079293] [1.1332405]
# 180 0.00017683291 [0.9913959] [1.1310636]
# 200 0.00015442724 [0.9919594] [1.1290292]
# 220 0.00013486316 [0.992486] [1.1271278]
# 240 0.00011777608 [0.9929781] [1.1253513]
# 260 0.00010285461 [0.993438] [1.1236911]
# 280 8.982574e-05 [0.9938677] [1.1221396]
# 300 7.844441e-05 [0.99426925] [1.1206895]
# 320 6.8505666e-05 [0.99464464] [1.1193345]
# 340 5.9824342e-05 [0.9949954] [1.1180681]
# 360 5.2245043e-05 [0.9953232] [1.1168848]
# 380 4.562721e-05 [0.9956295] [1.1157789]
# 400 3.9843926e-05 [0.9959158] [1.1147451]
# 420 3.4795776e-05 [0.9961833] [1.1137794]
# 440 3.0387328e-05 [0.99643326] [1.112877]
# 460 2.6537562e-05 [0.99666685] [1.1120337]
# 480 2.3175735e-05 [0.99688506] [1.1112458]
# 500 2.024056e-05 [0.9970891] [1.1105094]
# 520 1.7677708e-05 [0.99727964] [1.1098214]
# 540 1.5437807e-05 [0.9974578] [1.1091781]
# 560 1.3481261e-05 [0.9976243] [1.108577]
# 580 1.1774176e-05 [0.9977799] [1.1080153]
# 600 1.0281557e-05 [0.9979253] [1.1074903]
# 620 8.979211e-06 [0.9980612] [1.1069998]
# 640 7.840486e-06 [0.9981882] [1.1065412]
# 660 6.847184e-06 [0.9983068] [1.1061126]
# 680 5.9799063e-06 [0.99841774] [1.1057123]
# 700 5.222506e-06 [0.9985214] [1.1053382]
# 720 4.561579e-06 [0.9986182] [1.1049889]
# 740 3.9835645e-06 [0.99870867] [1.1046621]
# 760 3.4784257e-06 [0.99879324] [1.1043568]
# 780 3.0377637e-06 [0.9988723] [1.1040714]
# 800 2.6533726e-06 [0.9989461] [1.1038048]
# 820 2.3170687e-06 [0.99901515] [1.1035557]
# 840 2.0232656e-06 [0.99907964] [1.1033226]
# 860 1.7667319e-06 [0.9991399] [1.1031051]
# 880 1.543149e-06 [0.9991963] [1.1029017]
# 900 1.3477978e-06 [0.99924886] [1.1027118]
# 920 1.1769101e-06 [0.99929804] [1.1025342]
# 940 1.0280015e-06 [0.999344] [1.1023682]
# 960 8.977264e-07 [0.9993869] [1.1022133]
# 980 7.8399864e-07 [0.9994271] [1.1020683]
# 1000 6.845763e-07 [0.9994646] [1.1019329]
# 1020 5.978685e-07 [0.9994997] [1.1018063]
# 1040 5.2225056e-07 [0.9995324] [1.101688]
# 1060 4.5617176e-07 [0.99956304] [1.1015774]
# 1080 3.9831056e-07 [0.99959165] [1.1014742]
# 1100 3.4776076e-07 [0.9996185] [1.1013776]
# 1120 3.0370066e-07 [0.9996434] [1.1012872]
# 1140 2.6531126e-07 [0.9996667] [1.1012031]
# 1160 2.3163834e-07 [0.99968857] [1.1011243]
# 1180 2.0237144e-07 [0.99970895] [1.1010507]
# 1200 1.7670004e-07 [0.9997279] [1.1009821]
# 1220 1.5438916e-07 [0.9997457] [1.1009178]
# 1240 1.3483827e-07 [0.9997624] [1.1008576]
# 1260 1.1778894e-07 [0.999778] [1.1008016]
# 1280 1.0289968e-07 [0.99979246] [1.1007491]
# 1300 8.979646e-08 [0.999806] [1.1007001]
# 1320 7.851064e-08 [0.99981874] [1.1006542]
# 1340 6.853844e-08 [0.99983066] [1.1006114]
# 1360 5.983585e-08 [0.99984163] [1.1005715]
# 1380 5.226808e-08 [0.999852] [1.1005341]
# 1400 4.5712568e-08 [0.9998617] [1.1004993]
# 1420 3.9875204e-08 [0.9998708] [1.1004665]
# 1440 3.4801133e-08 [0.9998792] [1.100436]
# 1460 3.0448017e-08 [0.9998871] [1.1004074]
# 1480 2.6624605e-08 [0.9998944] [1.100381]
# 1500 2.3250697e-08 [0.99990135] [1.1003562]
# 1520 2.0280822e-08 [0.9999078] [1.1003326]
# 1540 1.7750256e-08 [0.9999138] [1.1003112]
# 1560 1.5486602e-08 [0.9999195] [1.1002907]
# 1580 1.3508452e-08 [0.99992466] [1.1002716]
# 1600 1.1843667e-08 [0.99992967] [1.1002542]
# 1620 1.0336828e-08 [0.99993426] [1.1002375]
# 1640 9.026655e-09 [0.99993855] [1.1002219]
# 1660 7.911694e-09 [0.9999424] [1.1002076]
# 1680 6.8715735e-09 [0.9999463] [1.1001936]
# 1700 6.070195e-09 [0.99994975] [1.1001817]
# 1720 5.2875064e-09 [0.999953] [1.1001698]
# 1740 4.5719846e-09 [0.9999562] [1.100158]
# 1760 4.0473878e-09 [0.9999588] [1.1001484]
# 1780 3.539128e-09 [0.99996144] [1.1001389]
# 1800 3.0649971e-09 [0.99996406] [1.1001294]
# 1820 2.6840667e-09 [0.9999665] [1.1001211]
# 1840 2.379295e-09 [0.99996847] [1.100114]
# 1860 2.0957145e-09 [0.99997044] [1.1001068]
# 1880 1.8305855e-09 [0.9999724] [1.1000997]
# 1900 1.5805199e-09 [0.9999743] [1.1000925]
# 1920 1.3694376e-09 [0.99997604] [1.1000863]
# 1940 1.2180976e-09 [0.99997735] [1.1000816]
# 1960 1.0809345e-09 [0.99997866] [1.1000768]
# 1980 9.523091e-10 [0.99998] [1.100072]
# 2000 8.319148e-10 [0.9999813] [1.1000673]

# %%
# 우리가 학습한 모델이 잘 작동하는지 테스트
print(sess.run(hypothesis, feed_dict={X: [5]}))
print(sess.run(hypothesis, feed_dict={X: [2.5]}))
print(sess.run(hypothesis, feed_dict={X: [1.5, 3.5]}))
# Out:
# [6.0999737]
# [3.6000204]
# [2.600039 4.600002]
